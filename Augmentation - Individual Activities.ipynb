# %%
import matplotlib.pylab as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.lines import Line2D
import numpy as np
import pandas as pd
import seaborn as sns

from ocddetection.data import SENSORS

# %%
def read_meta(path):
    df = pd.read_csv(path, index_col=0)
    df.index = pd.TimedeltaIndex(df.index).rename('ms')
    
    return df

# %%
meta = [
    [
        read_meta(f'./data/individual_activities/S{subject}-ADL{run}-META.csv')
        for run in range(1, 6)
    ]
    for subject in range(1, 5)
]

# %%
data = np.array([[run['ocd'].sum() / len(run) * 100 for run in adl] for adl in meta]).T
    
grid = sns.catplot(data=pd.DataFrame(data, columns=range(1, 5)), height=8, aspect=2)
grid.set(
    title='Fraction of OCD vs non-OCD behaviour',
    xlabel='Subject',
    ylabel='% of OCD behaviour'
)

plt.show()

# %% [markdown]
# ## Subject 1 (Drawer)

# %%
grid = sns.relplot(data=meta[0][0]['activity'], kind='line', height=8, aspect=2)

grid.set(
    title='Activity',
    xlabel='Time',
    ylabel=''
)

plt.show()

# %% [markdown]
# ## Subject 2 (Clean Table, Fridge)

# %%
grid = sns.relplot(data=meta[1][1]['activity'], kind='line', height=8, aspect=2)

grid.set(
    title='Activity',
    xlabel='Time',
    ylabel=''
)

plt.show()

# %% [markdown]
# ## Subject 3 (Toggle Switch, Dishwasher)

# %%
grid = sns.relplot(data=meta[2][2]['activity'], kind='line', height=8, aspect=2)

grid.set(
    title='Activity',
    xlabel='Time',
    ylabel=''
)

plt.show()

# %% [markdown]
# ## Subject 4 (Fridge, Dishwasher)

# %%
grid = sns.relplot(data=meta[3][3]['activity'], kind='line', height=8, aspect=2)

grid.set(
    title='Activity',
    xlabel='Time',
    ylabel=''
)

plt.show()
